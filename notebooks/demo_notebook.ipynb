# %% [markdown]
# # Kiro AI Agent Demo: ML Workflow on SageMaker
#
# Welcome to the **Kiro AI Agent Demo**! This notebook walks through a complete machine learning workflow using the classic Titanic dataset, with **Kiro** — the AI assistant built into your IDE — providing intelligent coding assistance at every step.
#
# ## What is Kiro?
#
# Kiro is an AI-powered IDE that connects to your development environment and helps you write, debug, and improve code through natural language interaction. In this demo, Kiro is connected to this SageMaker Notebook instance and can:
#
# - Generate Python code for data analysis and ML tasks
# - Suggest feature engineering strategies
# - Train and evaluate models
# - Explain its reasoning and suggest improvements
#
# ## How This Demo Works
#
# Each section below presents a step in the ML workflow. At each step, you will:
#
# 1. Read the context explaining what we want to accomplish
# 2. Use the suggested **Kiro prompt** to ask Kiro for help
# 3. Paste and execute Kiro's generated code in the empty code cell
#
# Let's get started!

# %% [markdown]
# ---
# ## 2. Data Loading
#
# The first step in any ML project is loading and inspecting the data. The Titanic dataset has already been pre-loaded into the `./data/` directory on this notebook instance. Let's ask Kiro to load it and show us what we're working with.
#
# > 🤖 **Kiro Prompt:** Load the Titanic dataset from `./data/titanic.csv` and display the first 10 rows

# %% [markdown]
# ---
# ## 3. Data Exploration
#
# Now that we have the data loaded, we need to understand its structure and distributions. Exploratory data analysis (EDA) helps us identify patterns, relationships between features, and potential issues before we start modeling.
#
# > 🤖 **Kiro Prompt:** Generate summary statistics and visualize the distribution of key features

# %% [markdown]
# ---
# ## 4. Missing Value Analysis
#
# Real-world datasets almost always have missing values. The Titanic dataset is no exception — columns like `Age` and `Cabin` have significant gaps. Understanding and handling missing data is critical before training a model.
#
# > 🤖 **Kiro Prompt:** Identify missing values and suggest imputation strategies

# %% [markdown]
# ---
# ## 5. Feature Engineering
#
# Feature engineering is where domain knowledge meets data science. By transforming raw features into more informative representations, we can significantly improve model performance. Let's see what Kiro suggests for the Titanic dataset.
#
# > 🤖 **Kiro Prompt:** Suggest and implement feature transformations to improve model performance

# %% [markdown]
# ---
# ## 6. Model Training
#
# With our features prepared, it's time to train a classification model. We'll use scikit-learn's Random Forest classifier — a robust, interpretable algorithm well-suited for tabular data like the Titanic dataset.
#
# > 🤖 **Kiro Prompt:** Train a Random Forest classifier with proper train-test split

# %% [markdown]
# ---
# ## 7. Model Evaluation
#
# Training a model is only half the battle. We need to evaluate how well it performs on unseen data using appropriate classification metrics and visualizations like confusion matrices.
#
# > 🤖 **Kiro Prompt:** Evaluate the model with classification metrics and a confusion matrix

# %% [markdown]
# ---
# ## 8. Model Improvement
#
# There's always room to improve. Let's ask Kiro to suggest ways to boost our model's performance — whether through hyperparameter tuning, trying different algorithms, or ensemble methods.
#
# > 🤖 **Kiro Prompt:** Suggest hyperparameter tuning or alternative algorithms to improve performance

# %% [markdown]
# ---
# ## 9. Summary
#
# In this demo, we walked through a complete ML workflow with Kiro as our AI coding assistant:
#
# 1. **Data Loading** — Loaded and inspected the Titanic dataset
# 2. **Data Exploration** — Generated summary statistics and visualizations
# 3. **Missing Value Analysis** — Identified gaps and applied imputation strategies
# 4. **Feature Engineering** — Transformed raw features to improve model inputs
# 5. **Model Training** — Trained a Random Forest classifier with proper data splitting
# 6. **Model Evaluation** — Assessed performance with metrics and confusion matrix
# 7. **Model Improvement** — Explored hyperparameter tuning and alternative approaches
#
# At each step, Kiro provided contextually relevant code, explanations, and suggestions — accelerating the workflow and reducing the manual effort typically required in ML development.
#
# ### Key Takeaways
#
# - Kiro understands the ML workflow context and generates appropriate code for each stage
# - Kiro works directly in your SageMaker environment, with access to your data and workspace
# - The AI assistant handles boilerplate code so you can focus on the data science decisions that matter
#
# Thank you for attending the demo!
